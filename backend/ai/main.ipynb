# %%
# 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # init

# %%
# %cd /content/drive/MyDrive/helpet/backend/ai

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# !which conda  # should return /usr/local/bin/conda
# !conda --version

# %%
# !conda create -n envname python==3.7

# %%
# %pip install -r requirements.txt

# %% [markdown]
# # Conjunctivitis Training

# %%
# %cd /content/drive/MyDrive/helpet/backend/ai/eye-diagnosis-model-training/conjunctivitis

# %%
# !python efficientNet_ai_train.py

# %%
# !python efficientNet_ai_test.py

# %% [markdown]
# # Server

# %%
# %cd /content/drive/MyDrive/helpet/backend/ai/fastapi

# %%
# !pip install colabcode
# !pip install fastapi

# %%
# !python server.py
